# %%
##PACKAGE PLAY
import numpy as np
print(np.pi)
print(np.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
x=np.linspace(0,np.pi,10)
print(x)
# Out:
# [0.         0.34906585 0.6981317  1.04719755 1.3962634  1.74532925
#  2.0943951  2.44346095 2.7925268  3.14159265]

# %%
y=np.sin(x)
print(y)
# Out:
# [0.00000000e+00 3.42020143e-01 6.42787610e-01 8.66025404e-01
#  9.84807753e-01 9.84807753e-01 8.66025404e-01 6.42787610e-01
#  3.42020143e-01 1.22464680e-16]

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.savefig("sinus.png")

# %%
from scipy.stats import norm

p = norm.rvs(loc=0, scale=10, size=10)

print(p)
# Out:
# [13.4414103  11.86276321 -2.84558941  6.77645996 -9.72317091 10.14973426
#  17.21906504 -3.70238037  7.96387104 -8.51033108]

# %%
#OS PLAY
